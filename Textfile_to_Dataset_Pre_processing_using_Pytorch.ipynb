# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U torchtext==0.6.0
import spacy
import pandas as pd
from torchtext.data import Field, BucketIterator, TabularDataset
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: torchtext==0.6.0 in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.9.0+cu102)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (0.1.96)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.6.0) (3.7.4.3)

# %%
#Downloading and Cloning INDICNLP
# !git clone "https://github.com/anoopkunchukuttan/indic_nlp_library"
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git
# !pip install Morfessor

# The path to the local git repo for Indic NLP library
INDIC_NLP_LIB_HOME=r"/content/indic_nlp_library"

# The path to the local git repo for Indic NLP Resources
INDIC_NLP_RESOURCES="/content/indic_nlp_resources"
# Out:
# Cloning into 'indic_nlp_library'...
# remote: Enumerating objects: 1325, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 1325 (delta 84), reused 89 (delta 41), pack-reused 1178
# Receiving objects: 100% (1325/1325), 9.57 MiB | 6.30 MiB/s, done.
# Resolving deltas: 100% (688/688), done.
# Cloning into 'indic_nlp_resources'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 133 (delta 0), reused 2 (delta 0), pack-reused 126
# Receiving objects: 100% (133/133), 149.77 MiB | 25.36 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Collecting Morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Installing collected packages: Morfessor
# Successfully installed Morfessor-2.0.6

# %%
import sys
sys.path.append(r'{}'.format(INDIC_NLP_LIB_HOME))

from indicnlp import common
common.set_resources_path(INDIC_NLP_RESOURCES)

#Load IndicNLP library
from indicnlp import loader
loader.load()

# %%
hindi_txt = open('/content/drive/MyDrive/processed.hi', encoding = 'utf8').read().split('\n')
english_txt = open('/content/drive/MyDrive/processed.en', encoding = 'utf8').read().split('\n')

# %%
hindi_txt[:10]
# Out:
# ['आदि में परमेश्वर ने आकाश और पृथ्वी की सृष्टि की ।',
#  'और पृथ्वी बेडौल और सुनसान पड़ी थी ; और गहरे जल के ऊपर अन्धियारा था : तथा परमेश्वर का आत्मा जल के ऊपर मण्डलाता था ।',
#  'तब परमेश्वर ने कहा , उजियाला हो : तो उजियाला हो गया ।',
#  'और परमेश्वर ने उजियाले को देखा कि अच्छा है ; और परमेश्वर ने उजियाले को अन्धियारे से अलग किया ।',
#  'और परमेश्वर ने उजियाले को दिन और अन्धियारे को रात कहा । तथा सांझ हुई फिर भोर हुआ । इस प्रकार पहिला दिन हो गया । ।',
#  'फिर परमेश्वर ने कहा , जल के बीच एक ऐसा अन्तर हो कि जल दो भाग हो जाए ।',
#  'तब परमेश्वर ने एक अन्तर करके उसके नीचे के जल और उसके ऊपर के जल को अलग अलग किया ; और वैसा ही हो गया ।',
#  'और परमेश्वर ने उस अन्तर को आकाश कहा । तथा सांझ हुई फिर भोर हुआ । इस प्रकार दूसरा दिन हो गया । ।',
#  'फिर परमेश्वर ने कहा , आकाश के नीचे का जल एक स्थान में इकट्ठा हो जाए और सूखी भूमि दिखाई दे ; और वैसा ही हो गया ।',
#  'और परमेश्वर ने सूखी भूमि को पृथ्वी कहा ; तथा जो जल इकट्ठा हुआ उसको उस ने समुद्र कहा : और परमेश्वर ने देखा कि अच्छा है ।']

# %%
english_txt[:10]
# Out:
# ['In the beginning God created the heaven and the earth .',
#  'And the earth was without form , and void ; and darkness was upon the face of the deep . And the Spirit of God moved upon the face of the waters .',
#  'And God said , Let there be light : and there was light .',
#  'And God saw the light , that it was good : and God divided the light from the darkness .',
#  'And God called the light Day , and the darkness he called Night . And the evening and the morning were the first day .',
#  'And God said , Let there be a firmament in the midst of the waters , and let it divide the waters from the waters .',
#  'And God made the firmament , and divided the waters which were under the firmament from the waters which were above the firmament : and it was so .',
#  'And God called the firmament Heaven . And the evening and the morning were the second day .',
#  'And God said , Let the waters under the heaven be gathered together unto one place , and let the dry land appear : and it was so .',
#  'And God called the dry land Earth ; and the gathering together of the waters called he Seas : and God saw that it was good .']

# %%
raw_data = {'Hindi' : [line for line in hindi_txt],
            'English' : [line for line in english_txt]}

# %%
df = pd.DataFrame(raw_data, columns = ['Hindi', 'English'])
df[:10]
# Out:
#                                                Hindi                                            English
# 0  आदि में परमेश्वर ने आकाश और पृथ्वी की सृष्टि की ।  In the beginning God created the heaven and th...
# 1  और पृथ्वी बेडौल और सुनसान पड़ी थी ; और गहरे जल...  And the earth was without form , and void ; an...
# 2  तब परमेश्वर ने कहा , उजियाला हो : तो उजियाला ह...  And God said , Let there be light : and there ...
# 3  और परमेश्वर ने उजियाले को देखा कि अच्छा है ; औ...  And God saw the light , that it was good : and...
# 4  और परमेश्वर ने उजियाले को दिन और अन्धियारे को ...  And God called the light Day , and the darknes...
# 5  फिर परमेश्वर ने कहा , जल के बीच एक ऐसा अन्तर ह...  And God said , Let there be a firmament in the...
# 6  तब परमेश्वर ने एक अन्तर करके उसके नीचे के जल औ...  And God made the firmament , and divided the w...
# 7  और परमेश्वर ने उस अन्तर को आकाश कहा । तथा सांझ...  And God called the firmament Heaven . And the ...
# 8  फिर परमेश्वर ने कहा , आकाश के नीचे का जल एक स्...  And God said , Let the waters under the heaven...
# 9  और परमेश्वर ने सूखी भूमि को पृथ्वी कहा ; तथा ज...  And God called the dry land Earth ; and the ga...

# %%
train, test = train_test_split(df, test_size = 0.1)
train.to_json('train.json', orient = 'records', lines = True)
test.to_json('test.json', orient = 'records', lines = True)

# %%
from indicnlp.tokenize import indic_tokenize  

#Tokenizing hindi sentences
def TokenizeHindi(indic_string):
    return indic_tokenize.trivial_tokenize(indic_string)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

#Tokenizing English sentences
def TokenizeEnglish(text):
  return [token for token in word_tokenize(text)]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
hindi = Field(sequential = True, use_vocab = True, tokenize = TokenizeHindi, lower = True)
english = Field(sequential = True, use_vocab = True, tokenize = TokenizeEnglish, lower = True)

# %%
fields = {'Hindi': ('hi', hindi), 'English': ('eng', english)}

# %%
train_data, test_data = TabularDataset.splits(
    path = '',
    train = 'train.json',
    test = 'test.json',
    format = 'json',
    fields = fields
)

# %%
hindi.build_vocab(train_data, max_size = 10000, min_freq = 2)
english.build_vocab(train_data, max_size = 10000, min_freq = 2)

# %%
train_iterator, trat_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size = 64,
    device = 'cuda'
)

# %%
for batch in train_iterator:
  print(batch)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 71x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 86x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 91x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 126x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 82x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 91x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 110x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 71x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 97x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 86x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 82x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 81x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 75x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 82x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 83x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 75x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 79x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 86x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 92x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 82x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 73x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 95x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 76x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 73x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 81x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 79x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 83x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 105x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 104x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 75x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 73x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 90x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 83x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 80x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 91x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 71x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 71x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 73x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# ...
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 91x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 68x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 90x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 84x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 26]
# 	[.hi]:[torch.cuda.LongTensor of size 38x26 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 43x26 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 79x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 75x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 80x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 81x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 58x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 80x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 37x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 77x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 53x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 62x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 51x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 78x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 90x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 57x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 71x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 70x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 94x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 80x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 80x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 75x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 74x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 65x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 61x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 67x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 42x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 52x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 63x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 72x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 69x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 45x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 66x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 47x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 64x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 59x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 55x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 50x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 60x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 46x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 49x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 56x64 (GPU 0)]
#
# [torchtext.data.batch.Batch of size 64]
# 	[.hi]:[torch.cuda.LongTensor of size 54x64 (GPU 0)]
# 	[.eng]:[torch.cuda.LongTensor of size 48x64 (GPU 0)]
